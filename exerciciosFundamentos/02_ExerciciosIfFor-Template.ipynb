# %% [markdown]
# # Questão 1: Verificar se um número é positivo, negativo ou zero
# Solicite ao usuário um número e verifique se ele é positivo, negativo ou zero.

# %% [markdown]
# # Questão 2: Verificar se um número é par ou ímpar
# Solicite ao usuário um número e verifique se ele é par ou ímpar.

# %% [markdown]
# # Questão 3: Verificar se uma string contém a letra 'a'
# Solicite ao usuário uma string e verifique se ela contém a letra 'a'.

# %% [markdown]
# # Questão 4: Verificar se um número é primo
# Solicite ao usuário um número e verifique se ele é primo.

# %% [markdown]
# # Questão 6: Imprimir números de 1 até um número informado
# Solicite ao usuário um número e imprima todos os números de 1 até o número informado.

# %% [markdown]
# # Questão 7: Contar vogais em uma string
# Solicite ao usuário uma string e conte quantas vogais ela contém.

# %% [markdown]
# # Questão 8: Imprimir a tabuada de um número
# Solicite ao usuário um número e imprima a tabuada desse número de 1 a 10.

# %% [markdown]
# # Questão 9: Verificar se uma string contém apenas números
# Solicite ao usuário uma string e verifique se ela contém apenas números.

# %% [markdown]
# # Questão 10: Calcular o fatorial de um número
# Solicite ao usuário um número e calcule o fatorial desse número.

# %% [markdown]
# # Questão 11: Verificar se uma string contém pelo menos uma letra maiúscula
# Solicite ao usuário uma string e verifique se ela contém pelo menos uma letra maiúscula.

# %% [markdown]
# # Questão 12: Verificar se um número é divisível por 3 e 5
# Solicite ao usuário um número e verifique se ele é divisível por 3 e por 5 ao mesmo tempo.

# %% [markdown]
# # Questão 13: Substituir vogais por '*' em uma string
# Solicite ao usuário uma string e substitua todas as vogais por '*'.

# %% [markdown]
# # Questão 14: Imprimir números pares de 0 até um número informado
# Solicite ao usuário um número e imprima todos os números pares de 0 até o número informado.

# %% [markdown]
# # Questão 15: Verificar se uma string termina com uma palavra específica
# Solicite ao usuário uma string e uma palavra, e verifique se a string termina com essa palavra.

# %% [markdown]
# # Questão 16: Verificar se um número é perfeito
# Solicite ao usuário um número e verifique se ele é um número perfeito.

# %% [markdown]
# # Questão 17: Verificar se um número é um quadrado perfeito
# Solicite ao usuário um número e verifique se ele é um quadrado perfeito.

# %% [markdown]
# # Questão 18: Verificar se um número pertence à sequência de Fibonacci
# Solicite ao usuário um número e verifique se ele é um número de Fibonacci.
